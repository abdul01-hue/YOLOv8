# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# %cd ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 83476, done.
# remote: Counting objects: 100% (275/275), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 83476 (delta 208), reused 77 (delta 76), pack-reused 83201 (from 4)
# Receiving objects: 100% (83476/83476), 44.73 MiB | 16.21 MiB/s, done.
# Resolving deltas: 100% (63003/63003), done.
# /content/ultralytics

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.6 MB/s eta 0:00:00

# %%
import os
import urllib.request

# Create weights directory
weights_dir = os.path.join(os.getcwd(), 'weights')
os.makedirs(weights_dir, exist_ok=True)

# YOLOv8 weight URLs
urls = [
    "https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt",
    "https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt",
    "https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8m.pt",
    "https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8l.pt",
    "https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8x.pt"
]

# Download weights
for url in urls:
    filename = os.path.basename(url)
    filepath = os.path.join(weights_dir, filename)
    urllib.request.urlretrieve(url, filepath)
    print(f"Downloaded: {filepath}")
# Out:
# Downloaded: /content/ultralytics/weights/yolov8n.pt
# Downloaded: /content/ultralytics/weights/yolov8s.pt
# Downloaded: /content/ultralytics/weights/yolov8m.pt
# Downloaded: /content/ultralytics/weights/yolov8l.pt
# Downloaded: /content/ultralytics/weights/yolov8x.pt

# %%
# !gdown "https://drive.google.com/uc?id=1q-sNrJfUi6PjvT8mFfEw1Cq4eCavdklK&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1q-sNrJfUi6PjvT8mFfEw1Cq4eCavdklK&confirm=t
# To: /content/ultralytics/image1.jpg
# 100% 214k/214k [00:00<00:00, 101MB/s]

# %%
# !yolo task=detect mode=predict save=True model=weights/yolov8x.pt source="image1.jpg"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8x summary (fused): 112 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
#
# image 1/1 /content/ultralytics/image1.jpg: 448x640 12 persons, 1 bicycle, 1 bus, 1 traffic light, 2 backpacks, 5 handbags, 3275.2ms
# Speed: 15.9ms preprocess, 3275.2ms inference, 41.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/ultralytics/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image(filename='runs/detect/predict/image1.jpg')

# %%
# !gdown "https://drive.google.com/uc?id=1hl_NNFciFwImmqplL3RkozpiIa8I38cd&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hl_NNFciFwImmqplL3RkozpiIa8I38cd&confirm=t
# To: /content/ultralytics/demo.mp4
# 100% 11.5M/11.5M [00:00<00:00, 43.8MB/s]

# %%
# !yolo task=detect mode=predict save=True model=weights/yolov8x.pt source="demo.mp4"
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8x summary (fused): 112 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
#
# video 1/1 (frame 1/1314) /content/ultralytics/demo.mp4: 384x640 4 cars, 1 truck, 3524.1ms
# video 1/1 (frame 2/1314) /content/ultralytics/demo.mp4: 384x640 3 cars, 1 truck, 2996.2ms
# video 1/1 (frame 3/1314) /content/ultralytics/demo.mp4: 384x640 3 cars, 1 truck, 2653.8ms
# video 1/1 (frame 4/1314) /content/ultralytics/demo.mp4: 384x640 4 cars, 1 truck, 2694.4ms
# video 1/1 (frame 5/1314) /content/ultralytics/demo.mp4: 384x640 6 cars, 1 truck, 2913.6ms
# video 1/1 (frame 6/1314) /content/ultralytics/demo.mp4: 384x640 6 cars, 2 trucks, 3485.3ms
# video 1/1 (frame 7/1314) /content/ultralytics/demo.mp4: 384x640 6 cars, 1 truck, 2640.8ms
# video 1/1 (frame 8/1314) /content/ultralytics/demo.mp4: 384x640 6 cars, 2 trucks, 2676.3ms
# ...

# %%
# !rm -f /content/result_compressed.mp4

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Output video path
save_path = 'runs/detect/predict2/demo.avi'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

# Convert video
os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Display video
mp4 = open(compressed_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML(f"""
<video width=600 controls>
  <source src="{data_url}" type="video/mp4">
</video>
""")
